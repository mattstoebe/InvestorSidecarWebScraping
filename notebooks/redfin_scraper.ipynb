# %%
from redfin_scraping_utils import BuyScraper

# %%
import pandas as pd
import numpy as np

# %%
# Initialize scraper
buy_scraper = BuyScraper()

# %%
# parameters
state_to_zip_codes = {
    'ID': ['98711', '83705'],
    'WA': ['98155', '98177']
    # Add more states/zips as needed, e.g. 'WA': ['98101', '98103']
}

# %%
# Initialize a new DataFrame for each state
buy_df = pd.DataFrame()

zip_codes = ['98711', '83705']
for zip_code in zip_codes:
    buy_data = buy_scraper.scrape_zip(zip_code, buy_scraper.get_default_params())
    if not buy_data.empty:
        buy_df = pd.concat([buy_df, buy_data], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 6
#       4 zip_codes = ['98711', '83705']
#       5 for zip_code in zip_codes:
# ----> 6     buy_data = buy_scraper.scrape_zip(zip_code, buy_scraper.get_default_params())
#       7     if not buy_data.empty:
#       8         buy_df = pd.concat([buy_df, buy_data], ignore_index=True)
#
# File /Users/mattstoebe/ClonedRepos/RealEstateWebScrapers/src/redfin_scraping_utils.py:53, in RedfinScraper.scrape_zip(self, zip_code, params)
#      52 def scrape_zip(self, zip_code, params):
# ---> 53     region_id = self.get_stingray_rgn_id(zip_code)
#      54     if region_id is None:
#      55         return pd.DataFrame()
#
# File /Users/mattstoebe/ClonedRepos/RealEstateWebScrapers/src/redfin_scraping_utils.py:23, in RedfinScraper.get_stingray_rgn_id(self, zip_code)
# ...
